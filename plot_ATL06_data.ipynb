# %%
from ATL06_tools import *
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ed0e9eba-402e-4c82-a863-d67323164d10">Loading BokehJS ...</span>
#     </div>

# %%
h = read_atl06('./test_data/ATL06_20151027T112254_00850305_943_01_sreq_524.h5')
h_03 = read_atl03('./test_data/ATL03_20151027T112254_00850305_943_01_sreq_525.h5')
atl06_handle = plot_atl03(h_03,x_axis='delta_time',hold='on',decimate=50) # hold = 'off' plots just ATL06
plot_atl06(h,x_axis='delta_time',hold='off',atl06_handle=atl06_handle) # just plot ATL03, to include ATL06, pass atl06_handle = atl06_handle
# plot_photon_channel_distributions(h_03)
# Out:
#   <div class="bk-root" id="f2141d3d-61f5-4ff0-ac2e-b2f5b97eadea"></div>
